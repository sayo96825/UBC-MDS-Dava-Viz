# %%
import pandas as pd
cereal_df = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/MCL-DSCI-511-programming-in-python/master/data/cereal.csv')
cereal_df.head()
# Out:
#                         name mfr  type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N  Cold        70        4    1     130   10.0
# 1          100% Natural Bran   Q  Cold       120        3    5      15    2.0
# 2                   All-Bran   K  Cold        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# 4             Almond Delight   R  Cold       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8       1        25      3     1.0  0.75  34.384843

# %%
cereal_df2 = pd.read_csv('https://raw.githubusercontent.com/UBC-MDS/MCL-DSCI-511-programming-in-python/master/data/cereal.csv',
                        usecols = ['name','mfr','type','calories','protein','weight','rating'])
cereal_df2.head()
# Out:
#                         name mfr  type  calories  protein  weight     rating
# 0                  100% Bran   N  Cold        70        4     1.0  68.402973
# 1          100% Natural Bran   Q  Cold       120        3     1.0  33.983679
# 2                   All-Bran   K  Cold        70        4     1.0  59.425505
# 3  All-Bran with Extra Fiber   K  Cold        50        4     1.0  93.704912
# 4             Almond Delight   R  Cold       110        2     1.0  34.384843

# %%
cereal_df['rating']
# Out:
# 0     68.402973
# 1     33.983679
# 2     59.425505
# 3     93.704912
# 4     34.384843
#         ...
# 72    39.106174
# 73    27.753301
# 74    49.787445
# 75    51.592193
# 76    36.187559
# Name: rating, Length: 77, dtype: float64

# %%
(cereal_df['rating'].round() // 10).astype('int')
# Out:
# 0     6
# 1     3
# 2     5
# 3     9
# 4     3
#      ..
# 72    3
# 73    2
# 74    5
# 75    5
# 76    3
# Name: rating, Length: 77, dtype: int32

# %%
cereal_df['rating'] / 10
# Out:
# 0     6.840297
# 1     3.398368
# 2     5.942551
# 3     9.370491
# 4     3.438484
#         ...
# 72    3.910617
# 73    2.775330
# 74    4.978744
# 75    5.159219
# 76    3.618756
# Name: rating, Length: 77, dtype: float64

# %%
cereal_df[cereal_df['protein'] > 4]
# Out:
#               name mfr  type  calories  protein  fat  sodium  fiber  carbo  \
# 11        Cheerios   G  Cold       110        6    2     290    2.0   17.0
# 57  Quaker Oatmeal   Q   Hot       100        5    2       0    2.7    1.0
# 67       Special K   K  Cold       110        6    0     230    1.0   16.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 11       1     105        25      1     1.0  1.25  50.764999
# 57       1     110         0      1     1.0  0.67  50.828392
# 67       3      55        25      1     1.0  1.00  53.131324

# %%
cereal_df[cereal_df['protein'] == 4]
# Out:
#                                  name mfr  type  calories  protein  fat  \
# 0                           100% Bran   N  Cold        70        4    1
# 2                            All-Bran   K  Cold        70        4    1
# 3           All-Bran with Extra Fiber   K  Cold        50        4    0
# 41                               Life   Q  Cold       100        4    2
# 43                              Maypo   A   Hot       100        4    1
# 44   Muesli Raisins; Dates; & Almonds   R  Cold       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R  Cold       150        4    3
# 56                 Quaker Oat Squares   Q  Cold       100        4    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0      130   10.0    5.0       6     280        25      3     1.0  0.33
# 2      260    9.0    7.0       5     320        25      3     1.0  0.33
# 3      140   14.0    8.0       0     330        25      3     1.0  0.50
# ...

# %%
cereal_df[cereal_df['protein'] >= 4]
# Out:
#                                  name mfr  type  calories  protein  fat  \
# 0                           100% Bran   N  Cold        70        4    1
# 2                            All-Bran   K  Cold        70        4    1
# 3           All-Bran with Extra Fiber   K  Cold        50        4    0
# 11                           Cheerios   G  Cold       110        6    2
# 41                               Life   Q  Cold       100        4    2
# 43                              Maypo   A   Hot       100        4    1
# 44   Muesli Raisins; Dates; & Almonds   R  Cold       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R  Cold       150        4    3
# 56                 Quaker Oat Squares   Q  Cold       100        4    1
# 57                     Quaker Oatmeal   Q   Hot       100        5    2
# 67                          Special K   K  Cold       110        6    0
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %%
cereal_df[(cereal_df['protein'] >= 4) & (cereal_df['protein'] <= 5)]
# Out:
#                                  name mfr  type  calories  protein  fat  \
# 0                           100% Bran   N  Cold        70        4    1
# 2                            All-Bran   K  Cold        70        4    1
# 3           All-Bran with Extra Fiber   K  Cold        50        4    0
# 41                               Life   Q  Cold       100        4    2
# 43                              Maypo   A   Hot       100        4    1
# 44   Muesli Raisins; Dates; & Almonds   R  Cold       150        4    3
# 45  Muesli Raisins; Peaches; & Pecans   R  Cold       150        4    3
# 56                 Quaker Oat Squares   Q  Cold       100        4    1
# 57                     Quaker Oatmeal   Q   Hot       100        5    2
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0      130   10.0    5.0       6     280        25      3     1.0  0.33
# 2      260    9.0    7.0       5     320        25      3     1.0  0.33
# ...

# %%
cereal_df[(cereal_df['mfr'] == 'Q') & (cereal_df['protein'] > 4)]
# Out:
#               name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 57  Quaker Oatmeal   Q  Hot       100        5    2       0    2.7    1.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 57       1     110         0      1     1.0  0.67  50.828392

# %%
cereal_df[(cereal_df['mfr'] == 'Q') | (cereal_df['protein'] > 4)]
# Out:
#                   name mfr  type  calories  protein  fat  sodium  fiber  \
# 1    100% Natural Bran   Q  Cold       120        3    5      15    2.0
# 10        Cap'n'Crunch   Q  Cold       120        1    2     220    0.0
# 11            Cheerios   G  Cold       110        6    2     290    2.0
# 35    Honey Graham Ohs   Q  Cold       120        1    2     220    1.0
# 41                Life   Q  Cold       100        4    2     150    2.0
# 54         Puffed Rice   Q  Cold        50        1    0       0    0.0
# 55        Puffed Wheat   Q  Cold        50        2    0       0    1.0
# 56  Quaker Oat Squares   Q  Cold       100        4    1     135    2.0
# 57      Quaker Oatmeal   Q   Hot       100        5    2       0    2.7
# 67           Special K   K  Cold       110        6    0     230    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# ...

# %%
cereal_df.loc[5:10]
# Out:
#                        name mfr  type  calories  protein  fat  sodium  fiber  \
# 5   Apple Cinnamon Cheerios   G  Cold       110        2    2     180    1.5
# 6               Apple Jacks   K  Cold       110        2    0     125    1.0
# 7                   Basic 4   G  Cold       130        3    2     210    2.0
# 8                 Bran Chex   R  Cold        90        2    1     200    4.0
# 9               Bran Flakes   P  Cold        90        3    0     210    5.0
# 10             Cap'n'Crunch   Q  Cold       120        1    2     220    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 5    10.5      10      70        25      1    1.00  0.75  29.509541
# 6    11.0      14      30        25      2    1.00  1.00  33.174094
# 7    18.0       8     100        25      3    1.33  0.75  37.038562
# 8    15.0       6     125        25      1    1.00  0.67  49.120253
# 9    13.0       5     190        25      3    1.00  0.67  53.313813
# ...

# %%
cereal_df.loc[4]
# Out:
# name        Almond Delight
# mfr                      R
# type                  Cold
# calories               110
# protein                  2
# fat                      2
# sodium                 200
# fiber                  1.0
# carbo                 14.0
# sugars                   8
# potass                   1
# vitamins                25
# shelf                    3
# weight                 1.0
# cups                  0.75
# rating           34.384843
# Name: 4, dtype: object

# %%
cereal_df.loc[[4]]
# Out:
#              name mfr  type  calories  protein  fat  sodium  fiber  carbo  \
# 4  Almond Delight   R  Cold       110        2    2     200    1.0   14.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 4       8       1        25      3     1.0  0.75  34.384843

# %%
cereal_df.loc[4,'sodium']
# Out:
# 200

# %%
cereal_df.loc[:6,'sugars':]
# Out:
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       6     280        25      3     1.0  0.33  68.402973
# 1       8     135         0      3     1.0  1.00  33.983679
# 2       5     320        25      3     1.0  0.33  59.425505
# 3       0     330        25      3     1.0  0.50  93.704912
# 4       8       1        25      3     1.0  0.75  34.384843
# 5      10      70        25      1     1.0  0.75  29.509541
# 6      14      30        25      2     1.0  1.00  33.174094

# %%
sorted_ratings = cereal_df.sort_values(by='rating',ascending = False)
sorted_ratings
# Out:
#                          name mfr  type  calories  protein  fat  sodium  \
# 3   All-Bran with Extra Fiber   K  Cold        50        4    0     140
# 64     Shredded Wheat 'n'Bran   N  Cold        90        3    0       0
# 65  Shredded Wheat spoon size   N  Cold        90        3    0       0
# 0                   100% Bran   N  Cold        70        4    1     130
# 63             Shredded Wheat   N  Cold        80        2    0       0
# ..                        ...  ..   ...       ...      ...  ...     ...
# 14                Cocoa Puffs   G  Cold       110        1    1     180
# 18              Count Chocula   G  Cold       110        1    1     180
# 35           Honey Graham Ohs   Q  Cold       120        1    2     220
# 12      Cinnamon Toast Crunch   G  Cold       120        1    3     210
# 10               Cap'n'Crunch   Q  Cold       120        1    2     220
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
mfr_column = cereal_df['mfr']
mfr_column
# Out:
# 0     N
# 1     Q
# 2     K
# 3     K
# 4     R
#      ..
# 72    G
# 73    G
# 74    R
# 75    G
# 76    G
# Name: mfr, Length: 77, dtype: object

# %%
mfr_freq = mfr_column.value_counts()
mfr_freq
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
cereal_df[cereal_df['mfr'] == 'Q']
# Out:
#                   name mfr  type  calories  protein  fat  sodium  fiber  \
# 1    100% Natural Bran   Q  Cold       120        3    5      15    2.0
# 10        Cap'n'Crunch   Q  Cold       120        1    2     220    0.0
# 35    Honey Graham Ohs   Q  Cold       120        1    2     220    1.0
# 41                Life   Q  Cold       100        4    2     150    2.0
# 54         Puffed Rice   Q  Cold        50        1    0       0    0.0
# 55        Puffed Wheat   Q  Cold        50        2    0       0    1.0
# 56  Quaker Oat Squares   Q  Cold       100        4    1     135    2.0
# 57      Quaker Oatmeal   Q   Hot       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 10   12.0      12      35        25      2     1.0  0.75  18.042851
# 35   12.0      11      45        25      2     1.0  1.00  21.871292
# ...

# %%
import altair as alt
chart0 = alt.Chart(cereal_df).mark_bar().encode(
    x='mfr',
    y='count()')

chart0
# Out:
# alt.Chart(...)

# %%
chart2 = alt.Chart(cereal_df).mark_circle(color='red',size=80, opacity=0.3).encode(
    x='sugars',
    y='calories')

chart2
# Out:
# alt.Chart(...)

# %%
cereal_df[cereal_df['mfr'] == 'K'].mean()[['sugars']]
# Out:
# C:\Users\sayo9\AppData\Local\Temp\ipykernel_21740\2121938281.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cereal_df[cereal_df['mfr'] == 'K'].mean()[['sugars']]
# sugars    7.565217
# dtype: float64

# %%
cereal_df[cereal_df['mfr'] == 'G'].mean()[['sugars']]
# Out:
# C:\Users\sayo9\AppData\Local\Temp\ipykernel_21740\1803835747.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cereal_df[cereal_df['mfr'] == 'G'].mean()[['sugars']]
# sugars    7.954545
# dtype: float64

# %%
mfr_group = cereal_df.groupby(by='mfr')
mfr_group

# %%
mfr_group.groups
# Out:
# {'A': [43], 'G': [5, 7, 11, 12, 13, 14, 18, 22, 31, 36, 40, 42, 47, 51, 59, 69, 70, 71, 72, 73, 75, 76], 'K': [2, 3, 6, 16, 17, 19, 21, 24, 25, 26, 28, 38, 39, 46, 48, 49, 50, 53, 58, 60, 62, 66, 67], 'N': [0, 20, 63, 64, 65, 68], 'P': [9, 27, 29, 30, 32, 33, 34, 37, 52], 'Q': [1, 10, 35, 41, 54, 55, 56, 57], 'R': [4, 8, 15, 23, 44, 45, 61, 74]}

# %%
mfr_group.groups['K']
# Out:
# Int64Index([ 2,  3,  6, 16, 17, 19, 21, 24, 25, 26, 28, 38, 39, 46, 48, 49, 50,
#             53, 58, 60, 62, 66, 67],
#            dtype='int64')

# %%
mfr_group.get_group("K").head()
# Out:
#                          name mfr  type  calories  protein  fat  sodium  \
# 2                    All-Bran   K  Cold        70        4    1     260
# 3   All-Bran with Extra Fiber   K  Cold        50        4    0     140
# 6                 Apple Jacks   K  Cold       110        2    0     125
# 16                Corn Flakes   K  Cold       100        2    0     290
# 17                  Corn Pops   K  Cold       110        1    0      90
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2     9.0    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0     330        25      3     1.0  0.50  93.704912
# 6     1.0   11.0      14      30        25      2     1.0  1.00  33.174094
# 16    1.0   21.0       2      35        25      1     1.0  1.00  45.863324
# 17    1.0   13.0      12      20        25      2     1.0  1.00  35.782791

# %%
cereal_df['mfr'].value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
mfr_group.size()
# Out:
# mfr
# A     1
# G    22
# K    23
# N     6
# P     9
# Q     8
# R     8
# dtype: int64

# %%
mfr_group.mean().reset_index
# Out:
# <bound method DataFrame.reset_index of        calories   protein       fat      sodium     fiber      carbo  \
# mfr
# A    100.000000  4.000000  1.000000    0.000000  0.000000  16.000000
# G    111.363636  2.318182  1.363636  200.454545  1.272727  14.727273
# K    108.695652  2.652174  0.608696  174.782609  2.739130  15.130435
# N     86.666667  2.833333  0.166667   37.500000  4.000000  16.000000
# P    108.888889  2.444444  0.888889  146.111111  2.777778  13.222222
# Q     95.000000  2.625000  1.750000   92.500000  1.337500  10.250000
# R    115.000000  2.500000  1.250000  198.125000  1.875000  17.625000
#
#        sugars      potass   vitamins     shelf    weight      cups     rating
# mfr
# A    3.000000   95.000000  25.000000  2.000000  1.000000  1.000000  54.850917
# G    7.954545   85.227273  35.227273  2.136364  1.049091  0.875000  34.485852
# K    7.565217  103.043478  34.782609  2.347826  1.077826  0.796087  44.038462
# ...

# %%
mfr_group.max()
# Out:
#                         name  type  calories  protein  fat  sodium  fiber  \
# mfr
# A                      Maypo   Hot       100        4    1       0    0.0
# G        Wheaties Honey Gold  Cold       140        6    3     290    4.0
# K                  Special K  Cold       160        6    3     320   14.0
# N    Strawberry Fruit Wheats   Hot       100        4    1     130   10.0
# P      Post Nat. Raisin Bran  Cold       120        3    3     210    6.0
# Q             Quaker Oatmeal   Hot       120        5    5     220    2.7
# R                 Wheat Chex  Cold       150        4    3     280    4.0
#
#      carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# mfr
# A     16.0       3      95        25      2    1.00  1.00  54.850917
# G     21.0      14     230       100      3    1.50  1.50  51.592193
# K     22.0      15     330       100      3    1.50  1.00  93.704912
# N     21.0       6     280        25      3    1.00  1.00  74.472949
# ...

# %%
cereal_df.agg('mean')
# Out:
# C:\Users\sayo9\AppData\Local\Temp\ipykernel_21740\1737481486.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cereal_df.agg('mean')
# calories    106.883117
# protein       2.545455
# fat           1.012987
# sodium      159.675325
# fiber         2.151948
# carbo        14.623377
# sugars        6.948052
# potass       96.129870
# vitamins     28.246753
# shelf         2.207792
# weight        1.029610
# cups          0.821039
# rating       42.665705
# dtype: float64

# %%
cereal_df.mean()
# Out:
# C:\Users\sayo9\AppData\Local\Temp\ipykernel_21740\3908737709.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cereal_df.mean()
# calories    106.883117
# protein       2.545455
# fat           1.012987
# sodium      159.675325
# fiber         2.151948
# carbo        14.623377
# sugars        6.948052
# potass       96.129870
# vitamins     28.246753
# shelf         2.207792
# weight        1.029610
# cups          0.821039
# rating       42.665705
# dtype: float64

# %%
cereal_df.agg(['max','min','median'])
# Out:
# C:\Users\sayo9\AppData\Local\Temp\ipykernel_21740\2086771719.py:1: FutureWarning: ['name', 'mfr', 'type'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   cereal_df.agg(['max','min','median'])
#                        name  mfr  type  calories  protein  fat  sodium  fiber  \
# max     Wheaties Honey Gold    R   Hot     160.0      6.0  5.0   320.0   14.0
# min               100% Bran    A  Cold      50.0      1.0  0.0     0.0    0.0
# median                  NaN  NaN   NaN     110.0      3.0  1.0   180.0    2.0
#
#         carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# max      23.0    15.0   330.0     100.0    3.0     1.5  1.50  93.704912
# min       1.0     0.0     1.0       0.0    1.0     0.5  0.25  18.042851
# median   14.0     7.0    90.0      25.0    2.0     1.0  0.75  40.400208

# %%
mfr_group.agg({'calories':['max','min'],
              'rating':['sum'],
              'sugars':['mean','median']})
# Out:
#     calories            rating    sugars
#          max  min          sum      mean median
# mfr
# A        100  100    54.850917  3.000000    3.0
# G        140  100   758.688737  7.954545    8.5
# K        160   50  1012.884634  7.565217    7.0
# N        100   70   407.811403  1.833333    0.0
# P        120   90   375.351697  8.777778   10.0
# Q        120   50   343.327919  5.500000    6.0
# R        150   90   332.343977  6.125000    5.5

# %%
cereal_df.head()
# Out:
#                         name mfr  type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N  Cold        70        4    1     130   10.0
# 1          100% Natural Bran   Q  Cold       120        3    5      15    2.0
# 2                   All-Bran   K  Cold        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K  Cold        50        4    0     140   14.0
# 4             Almond Delight   R  Cold       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8       1        25      3     1.0  0.75  34.384843

# %%
cereal_long = cereal_df[['name', 'mfr']]
cereal_long
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21740\3960847819.py in <module>
# ----> 1 cereal_long = cereal_df[['name', 'mfr','nutrition','value']]
#       2 cereal_long
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %%
sugar_rating_chart = alt.Chart(cereal_df,width=500, height=300).mark_circle().encode(
    x='sugars:Q',
    y='rating:Q').properties(title= 'Scatter plot of cereal rating vs sugar content')

sugar_rating_chart
# Out:
# alt.Chart(...)

# %%
calories_chart = alt.Chart(cereal_df).mark_bar().encode(
    x=alt.X('calories', bin=True),
    y='count()')
calories_chart
# Out:
# alt.Chart(...)

# %%
calories_chart = alt.Chart(cereal_df).mark_bar().encode(
    x=alt.X('calories', bin=alt.Bin(maxbins=20)),
    y='count()')
calories_chart
# Out:
# alt.Chart(...)

# %%
mfr_mean= cereal_df.groupby(by='mfr').mean()
mfr_mean.reset_index()
# Out:
#   mfr    calories   protein       fat      sodium     fiber      carbo  \
# 0   A  100.000000  4.000000  1.000000    0.000000  0.000000  16.000000
# 1   G  111.363636  2.318182  1.363636  200.454545  1.272727  14.727273
# 2   K  108.695652  2.652174  0.608696  174.782609  2.739130  15.130435
# 3   N   86.666667  2.833333  0.166667   37.500000  4.000000  16.000000
# 4   P  108.888889  2.444444  0.888889  146.111111  2.777778  13.222222
# 5   Q   95.000000  2.625000  1.750000   92.500000  1.337500  10.250000
# 6   R  115.000000  2.500000  1.250000  198.125000  1.875000  17.625000
#
#      sugars      potass   vitamins     shelf    weight      cups     rating
# 0  3.000000   95.000000  25.000000  2.000000  1.000000  1.000000  54.850917
# 1  7.954545   85.227273  35.227273  2.136364  1.049091  0.875000  34.485852
# 2  7.565217  103.043478  34.782609  2.347826  1.077826  0.796087  44.038462
# 3  1.833333  121.000000   8.333333  1.666667  0.971667  0.778333  67.968567
# ...

# %%
chart = alt.Chart(mfr_mean).mark_bar().encode(
    x=alt.X('mfr:N'),
    y=alt.Y('sugars:Q'))
chart
# Out:
# alt.Chart(...)
